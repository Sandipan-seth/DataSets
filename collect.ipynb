# %% [markdown]
# ***heading***

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns 
df=pd.read_csv("Contact Information.csv")
df.rename(columns={'Enter your name': 'Name',
                  'Username': 'Email id',
                  'Enter Your Phone Number(optional)': 'Phone no',
                  'What is your gender?':'Gender',
                  'Enter your city':'City',
                  'Which category of cab you used most?':'Most use',
                  'What is your age':'Age',
                  'When you mostly use this service':'Time',
                  'Your average spending per ride':'Spending',
                  'What is your primary purpose ':'Purpose',
                  'How much fare do you expect to reserve a toto per km ride?':'Expectation',
                  'How much distance you want to cover with toto/auto?':'Distance'}, inplace=True)
df.replace('Never', np.nan, inplace=True)
df.replace('18-25', np.mean([18,25]), inplace=True)
df.replace('50-60', np.mean([50,60]), inplace=True)
df.replace('26-30', np.mean([26,30]), inplace=True)
df.replace('30-40', np.mean([30,40]), inplace=True)
df['City'] = df['City'].str.upper()
df['City'] = df['City'].str.replace(' ', '')
df.loc[df['City'] == 'DURGAPUR', 'City']="RISHRA"
df.loc[df['City'] == 'SERAMPUR', 'City']="SERAMPORE"
df.loc[df['City'] == 'SHEORAPHULI', 'City']="SEORAPHULI"
# df.loc[df['Expectation'] == 'Nov-20', 'Expectation']="11-20"
df.to_csv('Contact Information.csv', index=False)
print(df)
# Out:
#                           Timestamp                      Email id  \
# 0    2024/06/20 4:20:12 pm GMT+5:30         coolraj.dey@gmail.com
# 1    2024/06/20 4:28:27 pm GMT+5:30      shreyabanik931@gmail.com
# 2    2024/06/20 4:30:34 pm GMT+5:30    dattaadrija17603@gmail.com
# 3    2024/06/20 4:30:52 pm GMT+5:30  kundusoumyadeep100@gmail.com
# 4    2024/06/20 4:32:28 pm GMT+5:30         isha.pal086@gmail.com
# ..                              ...                           ...
# 85   2024/06/21 7:16:36 pm GMT+5:30     pranayrakshit97@gmail.com
# 86   2024/06/21 9:55:06 pm GMT+5:30          sarupadas3@gmail.com
# 87  2024/06/21 10:05:24 pm GMT+5:30      niveditadey818@gmail.com
# 88   2024/06/22 4:18:41 am GMT+5:30     arkapravosrkr97@gmail.com
# 89   2024/06/22 7:52:28 pm GMT+5:30      soumyadiphui87@gmail.com
#
#                  Name      Phone no       City  Gender   Age Most use  \
# 0           Ayan Dey   9.830422e+09    KOLKATA    Male  55.0      Car
# ...

# %%
i=0
for city in df["City"]:
    if(city == "SERAMPORE"):
        i+=1
# print(i)

# %%
Name_of_city=list(df["City"])
print(Name_of_city)
# Out:
# ['KOLKATA', 'RISHRA', 'KONNAGAR', 'SERAMPORE', 'SERAMPORE', 'KOLKATA', 'UTTARPARA', 'KOLKATA', 'KOLKATA', 'SERAMPORE', 'WESTBENGAL', 'KOLKATA', 'HOOGHLY', 'SERAMPORE', 'KONNAGAR', 'SERAMPORE', 'RISHRA', 'HOWRAH', 'SERAMPORE', 'SERAMPORE', 'SERAMPORE', 'SERAMPORE', 'KONNAGAR', 'SERAMPORE', 'SERAMPORE', 'SERAMPORE', 'KONNAGAR', 'KONNAGAR', 'HOWRAH', 'SEORAPHULI', 'SERAMPORE', 'KOLKATA', 'SERAMPORE', 'SERAMPORE', 'HINDMOTOR', 'SERAMPORE', 'RISHRA', 'SERAMPORE', 'RISHRA', 'SERAMPORE', 'RISHRA', 'KONNAGAR', 'KONNAGAR', 'SERAMPORE', 'SERAMPORE', 'RISHRA', 'KOLKATA', 'SERAMPORE', 'SERAMPORE', 'KONNAGAR', 'SERAMPORE', 'RISHRA', 'SERAMPORE', 'KOLKATA', 'KONNAGAR', 'SERAMPORE', 'SERAMPORE', 'KOLKATA', 'SERAMPORE', 'KOLKATA', 'KONNAGAR', 'SERAMPORE', 'SERAMPORE', 'UTTARPARA', 'RISHRA', 'KONNAGAR', 'HOWRAH', 'RISHRA', 'KONNAGAR', 'SERAMPORE', 'KOLKATA', 'SERAMPORE', 'RISHRA', 'SERAMPORE', 'SERAMPORE', 'SERAMPORE', 'SERAMPORE', 'SERAMPORE', 'SERAMPORE', 'KOLKATA', 'KOLKATA', 'KOLKATA', 'SERAMPORE
# ...

# %%
df.to_csv('Contact Information.csv', index=False)

# %%
filtered_df = df[df['City'] == 'KONNAGAR']
df.loc[pd.isna(df['Name']),"Name"]="Someone"
filtered_df.to_csv('Konnagar.csv', index=False)

# %%
filteredSer_df = df[df['City'] == 'SERAMPORE']
filteredSer_df.to_csv('Serampore.csv', index=False)

# %%
count_serampore = (df['City'] == 'SERAMPORE').sum()
# print("\nNumber of entries where City is 'Serampore':", count_serampore)

# %%
# print(df["City"])

# %%
city_counts = df.groupby('City').size()

print(city_counts)
# Out:
# City
# BURDWAN        1
# HINDMOTOR      1
# HOOGHLY        1
# HOWRAH         3
# KHARAGPUR      1
# KOLKATA       15
# KONNAGAR      13
# RISHRA        10
# SEORAPHULI     2
# SERAMPORE     40
# UTTARPARA      2
# WESTBENGAL     1
# dtype: int64

# %%
names_per_city = df.groupby('City')['Name'].apply(list)
print(list(names_per_city.keys()))
# Out:
# ['BURDWAN', 'HINDMOTOR', 'HOOGHLY', 'HOWRAH', 'KHARAGPUR', 'KOLKATA', 'KONNAGAR', 'RISHRA', 'SEORAPHULI', 'SERAMPORE', 'UTTARPARA', 'WESTBENGAL']

# %%
print(list(names_per_city))
# Out:
# [['Pranay Rakshit'], ['Arunava Mukhopadhyay '], ['Anibrata Deb Barman '], ['Debanjan Dutta ', 'Suman Banerjee', 'Writabrata Sinha'], ['SOUMYADIP HUI'], ['Ayan Dey ', 'Satyaki Nandi ', 'Anwesha Sannyasi', 'Md Jasimuddin', 'Supratim Dasgupta ', 'Rahul Kumar Shaw ', 'Binita Shee', 'Shuvadip Sahoo ', 'Suvankar Saha', 'Ishita Datta ', 'Sampurna Srimani', 'Rudra Mukherjee ', 'Disha', 'Dipayan Mandal ', 'Nivedita dey '], ['Adrija Datta', 'Subhankar Roy', 'Sayak', 'SUBHRODEEP BANDYOPADHYAY', 'Subhranil Ghoshal', 'Swapnanil Mukherjee ', 'Asha Basu Mallick', 'Sanjib sen', 'Monika Choudhury ', 'Someone', 'Sayan Chakrabortty ', 'Soham Basak ', 'Arkapravo Sarkar '], ['Sreya Banik', 'Disha Khan ', 'Subham', 'Jit Nandi', 'Subhomita Das ', 'Arka Mukherjee ', 'Rishika Sharma ', 'Imon Ghosh ', 'MADHUBONI BHATTACHARYA', 'Debkanta Ghosh '], ['Rupak Samanta ', 'Shibam Pandit'], ['Soumyadeep Kundu', 'Isha Pal', 'Pritam Pal', 'Arghyadeep Singha', 'Sourav Kundu ', 'Sneha Das ', 'Piyasa panigrahi ', 'Kohina 
# ...

# %%
for city, group in df.groupby('City'):
    # Define the filename based on the city name
    filename = f"{city}.csv"
    # Save the group to a CSV file
    group.to_csv(filename, index=False)
    print(f"Saved {filename}")
# Out:
# Saved BURDWAN.csv
# Saved HINDMOTOR.csv
# Saved HOOGHLY.csv
# Saved HOWRAH.csv
# Saved KHARAGPUR.csv
# Saved KOLKATA.csv
# Saved KONNAGAR.csv
# Saved RISHRA.csv
# Saved SEORAPHULI.csv
# Saved SERAMPORE.csv
# Saved UTTARPARA.csv
# Saved WESTBENGAL.csv

# %%
dfSerampore = pd.read_csv('Serampore.csv')
plt.figure(figsize=(10, 6))  # Optional: Adjust the figure size for better readability
plt.scatter(dfSerampore['Name'], dfSerampore['Age'])  # Scatter plot
plt.xlabel('Name')
plt.ylabel('Mean Age')
plt.title('Age of Individuals by Name')
plt.xticks(rotation=90, ha='right')
plt.tight_layout()  # Adjust layout to prevent clipping of labels
plt.show()

# %%
print(dfSerampore["Time"])
# Out:
# 0                                          12 pm - 5 pm
# 1                                           6 pm - 9 pm
# 2                                          12 pm - 5 pm
# 3                                           6 pm - 9 pm
# 4                                          8 am - 11 am
# 5                                          9 pm - 12 am
# 6                                           6 pm - 9 pm
# 7                                          8 am - 11 am
# 8                                          12 pm - 5 pm
# 9                                         In Night time
# 10                                         8 am - 11 am
# 11                                        In Night time
# 12                                          6 pm - 9 pm
# 13                                I generally don't use
# 14                                         8 am - 11 am
# 15                                         8 am - 11 am
# 16                                         12 pm - 5 pm
# ...

# %%
# dfSerampore.loc[(dfSerampore["Time"]=="8 am - 11 am"),"Time"]="8.00-11.00"
# dfSerampore.loc[(dfSerampore["Time"]=="12 pm - 5 pm"),"Time"]="12.00-17.00"
# dfSerampore.loc[(dfSerampore["Time"]=="6 pm - 9 pm"),"Time"]="18.00-21.00"
# dfSerampore.loc[(dfSerampore["Time"]=="9 pm - 12 am"),"Time"]="21.00-00.00"
# dfSerampore.loc[(dfSerampore["Time"]=="In Night time"),"Time"]="00.00-7.00"
# dfSerampore.loc[(dfSerampore["Time"]=="No"),"Time"]="00"
# dfSerampore.loc[(dfSerampore["Time"]=="8 am - 11 am"),"Time"]="8.00-11.00"
# for i in range(1, len(dfSerampore)):
#     if df.loc[i, 'Time'] == "I generally don't use":
#         df.loc[i, 'Time'] = df.loc[i - 1, 'Time']

# %%
print(dfSerampore["Time"])
# Out:
# 0                                          12 pm - 5 pm
# 1                                           6 pm - 9 pm
# 2                                          12 pm - 5 pm
# 3                                           6 pm - 9 pm
# 4                                          8 am - 11 am
# 5                                          9 pm - 12 am
# 6                                           6 pm - 9 pm
# 7                                          8 am - 11 am
# 8                                          12 pm - 5 pm
# 9                                         In Night time
# 10                                         8 am - 11 am
# 11                                        In Night time
# 12                                          6 pm - 9 pm
# 13                                I generally don't use
# 14                                         8 am - 11 am
# 15                                         8 am - 11 am
# 16                                         12 pm - 5 pm
# ...

# %%
 # Define the specific time slots and their order
time_slots = ['8 am - 11 am', '12 pm - 5 pm', '6 pm - 9 pm', '9 pm - 12 am', 'In Night time']

# Filter and count the occurrences of the specific time slots
time_counts = dfSerampore['Time'].value_counts().reindex(time_slots, fill_value=0)

# Plot the bar graph
plt.figure(figsize=(10, 5))
time_counts.plot(kind='bar', color='skyblue')

# Set the labels and title
plt.xlabel('Time')
plt.ylabel('Count')
plt.title('Serampore People Usage Time of Car Service')

# Rotate the x-axis labels for better readability
plt.xticks(rotation=0, ha='center')

# Display the plot
plt.tight_layout()  # Adjust layout to prevent clipping of labels
plt.show()

# %%
plt.figure(figsize=(5, 6))
plt.pie(time_counts, labels=time_counts.index, autopct='%1.1f%%', startangle=200, colors=['gold', 'yellowgreen', 'lightcoral', 'lightskyblue'])
plt.title('Serampore People Usage Time of Car Service')
plt.axis('equal')
# Out:
# (-1.0999998926352108,
#  1.099997750520335,
#  -1.0999977410601045,
#  1.099994210616669)

# %%
time_slots = ['8 am - 11 am', '12 pm - 5 pm', '6 pm - 9 pm', '9 pm - 12 am', 'In Night time']

# Filter the DataFrame to include only the specific time slots
df_filtered = dfSerampore[dfSerampore['Time'].isin(time_slots)]

# Create a strip plot with Seaborn
plt.figure(figsize=(10, 6))
sns.stripplot(x='Time', data=df_filtered, jitter=True, dodge=True, palette='Set2')
plt.title('Distribution of Time Slots')
plt.xlabel('Time Slot')
plt.ylabel('Count of Occurrences')
# plt.xticks(rotation=45)
plt.grid(True)
plt.tight_layout()
plt.show()
# Out:
# C:\Users\SANDIPAN SETH\AppData\Local\Temp\ipykernel_16832\2221337528.py:8: FutureWarning: Passing `palette` without assigning `hue` is deprecated.
#   sns.stripplot(x='Time', data=df_filtered, jitter=True, dodge=True, palette='Set2')
# C:\Users\SANDIPAN SETH\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# C:\Users\SANDIPAN SETH\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):

# %%
desired_time_stamps = ['8 am - 11 am', '12 pm - 5 pm', '6 pm - 9 pm', '9 pm - 12 am', 'In Night time']

# Filter the DataFrame to include only the desired time stamps
df_filtered = dfSerampore[dfSerampore['Time'].isin(desired_time_stamps)]

# Count occurrences of each Name and Time combination
usage_counts = df_filtered.groupby(['Name', 'Time']).size().reset_index(name='Count')

# Create a pivot table for easier plotting
pivot_table = usage_counts.pivot(index='Name', columns='Time', values='Count').fillna(0)

# Reindex the pivot table columns to ensure the desired order
pivot_table = pivot_table.reindex(columns=desired_time_stamps)

# Plotting the heatmap
plt.figure(figsize=(15, 10))
sns.heatmap(pivot_table, cmap='Blues', annot=True, fmt="g")
plt.title('Density of Car Service Usage by Name and Time')
plt.xlabel('Time of Car Service')
plt.ylabel('Name')
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()

# %%
desired_time_slots = ['8 am - 11 am', '12 pm - 5 pm', '6 pm - 9 pm', '9 pm - 12 am','In Night time']
# Filter the DataFrame to include only the desired time slots
dfSerampore_filtered = dfSerampore[dfSerampore['Time'].isin(desired_time_slots)]
# Plotting the point plot
plt.figure(figsize=(10, 6))
sns.stripplot(x='Time', y='Name', data=dfSerampore_filtered, size=10, jitter=True, palette='Set2')
plt.title('Density of Car Service Usage in Serampore')
plt.xlabel('Time of Car Service')
plt.ylabel('Name')
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()
# Out:
# C:\Users\SANDIPAN SETH\AppData\Local\Temp\ipykernel_16832\3710349736.py:6: FutureWarning: Passing `palette` without assigning `hue` is deprecated.
#   sns.stripplot(x='Time', y='Name', data=dfSerampore_filtered, size=10, jitter=True, palette='Set2')
# C:\Users\SANDIPAN SETH\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# C:\Users\SANDIPAN SETH\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):

# %%
desired_time_stamps = ['8 am - 11 am', '12 pm - 5 pm', '6 pm - 9 pm', '9 pm - 12 am','In Night time']

# Filter the DataFrame to include only the desired time stamps
df_filtered = dfSerampore[dfSerampore['Time'].isin(desired_time_stamps)]

# Count occurrences of each time stamp
time_stamp_counts = df_filtered['Time'].value_counts().reindex(desired_time_stamps, fill_value=0)

# Plotting the line plot
plt.figure(figsize=(10, 6))
plt.plot(time_stamp_counts.index, time_stamp_counts.values, marker='o', linestyle='-', color='b', label='Count')
plt.title('Count of Specific Time Stamps')
plt.xlabel('Time Stamps')
plt.ylabel('Count')
plt.xticks(rotation=45)
plt.legend()
plt.tight_layout()
plt.show()

# %%
print(dfSerampore["spending"])
# Out:
# 0     Below 100
# 1       300-500
# 2       300-500
# 3       300-500
# 4       100-300
# 5       100-300
# 6       100-300
# 7       300-500
# 8       300-500
# 9       500-800
# 10    Below 100
# 11      100-300
# 12      100-300
# 13      100-300
# 14      100-300
# 15    Below 100
# 16      500-800
# 17      300-500
# 18    Below 100
# 19    Below 100
# 20      100-300
# 21      300-500
# 22      500-800
# 23     800-1000
# 24      500-800
# 25      300-500
# 26      300-500
# 27      100-300
# 28    Below 100
# 29      300-500
# 30     800-1000
# 31      100-300
# 32      100-300
# 33      100-300
# 34     800-1000
# 35    Below 100
# 36      500-800
# 37    Below 100
# 38      500-800
# 39      500-800
# Name: spending, dtype: object

# %%
# dfSerampore.loc[dfSerampore["spending"] == "100-300", "spending"] = np.mean([100, 300])
# dfSerampore.loc[dfSerampore["spending"] == "300-500", "spending"] = np.mean([300,500])
# dfSerampore.loc[dfSerampore["spending"] == "800-1000", "spending"] = np.mean([800,1000])
# dfSerampore.loc[dfSerampore["spending"] == "500-800", "spending"] = np.mean([500, 800])
# dfSerampore.loc[dfSerampore["spending"] == "Below 100", "spending"] = np.mean([0, 100])

# %%
print(dfSerampore["spending"])
# Out:
# 0     Below 100
# 1       300-500
# 2       300-500
# 3       300-500
# 4       100-300
# 5       100-300
# 6       100-300
# 7       300-500
# 8       300-500
# 9       500-800
# 10    Below 100
# 11      100-300
# 12      100-300
# 13      100-300
# 14      100-300
# 15    Below 100
# 16      500-800
# 17      300-500
# 18    Below 100
# 19    Below 100
# 20      100-300
# 21      300-500
# 22      500-800
# 23     800-1000
# 24      500-800
# 25      300-500
# 26      300-500
# 27      100-300
# 28    Below 100
# 29      300-500
# 30     800-1000
# 31      100-300
# 32      100-300
# 33      100-300
# 34     800-1000
# 35    Below 100
# 36      500-800
# 37    Below 100
# 38      500-800
# 39      500-800
# Name: spending, dtype: object

# %%
spending_categories = ['below 100', '100-300', '300-500', '500-800', '800-1000']

# Create a categorical dtype for 'spending' column to enforce order
spending_dtype = pd.api.types.CategoricalDtype(categories=spending_categories, ordered=True)
dfSerampore['spending'] = dfSerampore['spending'].astype(spending_dtype)

# Group by 'spending' and count occurrences of each 'Name'
spend_counts = dfSerampore.groupby('spending')['Name'].count()

# Plotting the point-line graph
plt.figure(figsize=(12, 6))
plt.plot(spend_counts.index, spend_counts.values, marker='o', linestyle='-', color='blue')

plt.title('Point-Line Graph of Spending vs Count of Name')
plt.xlabel('Spending')
plt.ylabel('Count of Name')
plt.xticks(rotation=45)  # Rotate x-axis labels if needed
plt.grid(True)  # Add gridlines
plt.tight_layout()
plt.show()
# Out:
# C:\Users\SANDIPAN SETH\AppData\Local\Temp\ipykernel_16832\159081974.py:8: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   spend_counts = dfSerampore.groupby('spending')['Name'].count()

# %%
spending_categories = ['below 100', '100-300', '300-500', '500-800', '800-1000']

# Create a categorical dtype for 'spending' column to enforce order
spending_dtype = pd.api.types.CategoricalDtype(categories=spending_categories, ordered=True)
dfSerampore['spending'] = dfSerampore['spending'].astype(spending_dtype)

# Group by 'spending' and count occurrences of each 'Name'
spend_counts = dfSerampore.groupby('spending')['Name'].count()

# Plotting the bar graph
plt.figure(figsize=(5, 5))
plt.bar(spend_counts.index, spend_counts.values, color='skyblue')

plt.title('Bar Graph of Spending vs Count of Name')
plt.xlabel('Spending')
plt.ylabel('Count of Name')
plt.xticks(rotation=45)  # Rotate x-axis labels if needed
plt.grid(axis='y')  # Add gridlines on y-axis
plt.tight_layout()
plt.show()
# Out:
# C:\Users\SANDIPAN SETH\AppData\Local\Temp\ipykernel_16832\3276688542.py:8: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   spend_counts = dfSerampore.groupby('spending')['Name'].count()

# %%
print(dfSerampore["spending"])
# Out:
# 0          NaN
# 1      300-500
# 2      300-500
# 3      300-500
# 4      100-300
# 5      100-300
# 6      100-300
# 7      300-500
# 8      300-500
# 9      500-800
# 10         NaN
# 11     100-300
# 12     100-300
# 13     100-300
# 14     100-300
# 15         NaN
# 16     500-800
# 17     300-500
# 18         NaN
# 19         NaN
# 20     100-300
# 21     300-500
# 22     500-800
# 23    800-1000
# 24     500-800
# 25     300-500
# 26     300-500
# 27     100-300
# 28         NaN
# 29     300-500
# 30    800-1000
# 31     100-300
# 32     100-300
# 33     100-300
# 34    800-1000
# 35         NaN
# 36     500-800
# 37         NaN
# 38     500-800
# 39     500-800
# Name: spending, dtype: category
# Categories (5, object): ['below 100' < '100-300' < '300-500' < '500-800' < '800-1000']

# %%
dfSerampore['spending'].fillna('below 100', inplace=True)

# %%
spend_counts = dfSerampore['spending'].value_counts()
plt.figure(figsize=(5,5))
plt.pie(spend_counts, labels=spend_counts.index, autopct='%1.1f%%', startangle=140, colors=['skyblue', 'lightgreen', 'lightcoral', 'lightskyblue', 'lightpink'])
plt.title('Distribution of Spending Categories')
plt.show()

# %%
print(df["Expectation"])
# Out:
# 0     11-20
# 1     11-20
# 2     11-20
# 3     31-40
# 4     11-20
#       ...
# 85    11-20
# 86    11-20
# 87    11-20
# 88    11-20
# 89    11-20
# Name: Expectation, Length: 90, dtype: object

# %%
# Group by 'purpose' and count occurrences of each 'Name'
purpose_counts = dfSerampore['Name'].groupby(dfSerampore['Purpose']).count()

# Plotting the bar graph
plt.figure(figsize=(5, 6))
plt.bar(purpose_counts.index, purpose_counts.values, color='skyblue')

plt.title('Bar Graph of Purpose vs Count of Name')
plt.xlabel('Purpose')
plt.ylabel('Count of Name')
plt.xticks(rotation=80)  # Rotate x-axis labels if needed
plt.grid(axis='y')  # Add gridlines on y-axis
plt.tight_layout()
plt.show()

# %%
# Group by 'purpose' and count occurrences of each 'Name'
purpose_counts = dfSerampore['Name'].groupby(dfSerampore['Purpose']).count()

# Plotting the bar graph
plt.figure(figsize=(5, 6))
plt.bar(purpose_counts.index, purpose_counts.values, color='skyblue')

plt.title('Bar Graph of Purpose vs Count of Name')
plt.xlabel('Purpose')
plt.ylabel('Count of Name')
plt.xticks(rotation=80)  # Rotate x-axis labels if needed
plt.grid(axis='y')  # Add gridlines on y-axis
plt.tight_layout()
plt.show()

# %%
# Group by 'purpose' and count occurrences of each 'Name'
purpose_counts = dfSerampore['Name'].groupby(dfSerampore['Most use']).count()

# Plotting the bar graph
plt.figure(figsize=(5, 4))
plt.bar(purpose_counts.index, purpose_counts.values, color='lightgreen')

plt.title('Bar Graph of Most use vehical vs Count of Name')
plt.xlabel('Most use vehical')
plt.ylabel('Count of Name')
# plt.xticks(rotation=25)  # Rotate x-axis labels if needed
plt.grid(axis='y')  # Add gridlines on y-axis
plt.tight_layout()
plt.show()

# %%
# Group by 'purpose' and count occurrences of each 'Name'
purpose_counts = dfSerampore['Name'].groupby(dfSerampore['Expectation']).count()

# Plotting the bar graph
plt.figure(figsize=(4,4))
plt.bar(purpose_counts.index, purpose_counts.values, color='black')

plt.title('Bar Graph of Expectation vs Count of Name')
plt.xlabel('Expectation')
plt.ylabel('Count of Name')
plt.grid(axis='y')  # Add gridlines on y-axis
plt.tight_layout()
plt.show()

# %%
purpose_counts = dfSerampore['Name'].groupby(dfSerampore['Distance']).count()

# Plotting the bar graph
plt.figure(figsize=(4,4))
plt.bar(purpose_counts.index, purpose_counts.values, color='yellow')

plt.title('Bar Graph of distance want to travel by Toto or Auto vs Count of Name')
plt.xlabel('distance want to travel by Toto')
plt.ylabel('Count of Name')
plt.grid(axis='y')  # Add gridlines on y-axis
plt.tight_layout()
plt.show()
